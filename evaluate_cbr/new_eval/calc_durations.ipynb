# %%
import pandas as pd

simple0 = pd.read_csv('results_simple_0.csv')
simple1 = pd.read_csv('results_simple_1.csv')
simple2 = pd.read_csv('results_simple_2.csv')
simple3 = pd.read_csv('results_simple_3.csv')
simple4 = pd.read_csv('results_simple_4.csv')
# Out:
#      Unnamed: 0  logical_ft_arg  logical_pt  srip_ft_arg   srip_pt  \
# 0   ndcg_burges        0.753732    0.767366     0.756194  0.759847
# 1          ndcg        0.813373    0.821088     0.804674  0.821923
# 2           map        0.787651    0.790227     0.782804  0.808207
# 3            f1        0.826797    0.826797     0.826797  0.826797
# 4        recall        0.994048    0.994048     0.994048  0.994048
# 5     precision        0.712500    0.712500     0.712500  0.712500
# 6   correctness        0.017186    0.001260    -0.060223  0.008134
# 7  completeness        0.992424    0.992424     0.992424  0.992424
# 8      duration        0.010967    0.005553     0.005522  0.005467
#
#    treemaps_ft_arg  treemaps_pt
# 0         0.750184     0.768819
# 1         0.806393     0.833303
# 2         0.781655     0.805139
# 3         0.826797     0.826797
# 4         0.994048     0.994048
# 5         0.712500     0.712500
# 6         0.073072     0.101478
# ...

# %%
# set duration to average of all runs
simple0.iloc[8, 1] = (simple0.iloc[8, 1] + simple1.iloc[8, 1] + simple2.iloc[8, 1] + simple3.iloc[8, 1] + simple4.iloc[8, 1]) / 5
simple0.iloc[8, 2] = (simple0.iloc[8, 2] + simple1.iloc[8, 2] + simple2.iloc[8, 2] + simple3.iloc[8, 2] + simple4.iloc[8, 2]) / 5
simple0.iloc[8, 3] = (simple0.iloc[8, 3] + simple1.iloc[8, 3] + simple2.iloc[8, 3] + simple3.iloc[8, 3] + simple4.iloc[8, 3]) / 5
simple0.iloc[8, 4] = (simple0.iloc[8, 4] + simple1.iloc[8, 4] + simple2.iloc[8, 4] + simple3.iloc[8, 4] + simple4.iloc[8, 4]) / 5
simple0.iloc[8, 5] = (simple0.iloc[8, 5] + simple1.iloc[8, 5] + simple2.iloc[8, 5] + simple3.iloc[8, 5] + simple4.iloc[8, 5]) / 5
simple0.iloc[8, 6] = (simple0.iloc[8, 6] + simple1.iloc[8, 6] + simple2.iloc[8, 6] + simple3.iloc[8, 6] + simple4.iloc[8, 6]) / 5
simple0
# Out:
#      Unnamed: 0  logical_ft_arg  logical_pt  srip_ft_arg   srip_pt  \
# 0   ndcg_burges        0.753732    0.767366     0.756194  0.759847
# 1          ndcg        0.813373    0.821088     0.804674  0.821923
# 2           map        0.787651    0.790227     0.782804  0.808207
# 3            f1        0.826797    0.826797     0.826797  0.826797
# 4        recall        0.994048    0.994048     0.994048  0.994048
# 5     precision        0.712500    0.712500     0.712500  0.712500
# 6   correctness        0.017186    0.001260    -0.060223  0.008134
# 7  completeness        0.992424    0.992424     0.992424  0.992424
# 8      duration        0.006632    0.006651     0.006444  0.005455
#
#    treemaps_ft_arg  treemaps_pt
# 0         0.750184     0.768819
# 1         0.806393     0.833303
# 2         0.781655     0.805139
# 3         0.826797     0.826797
# 4         0.994048     0.994048
# 5         0.712500     0.712500
# 6         0.073072     0.101478
# ...

# %%
import pandas as pd

complex0 = pd.read_csv('results_complex_0.csv')
complex1 = pd.read_csv('results_complex_1.csv')
complex2 = pd.read_csv('results_complex_2.csv')
complex3 = pd.read_csv('results_complex_3.csv')
complex4 = pd.read_csv('results_complex_4.csv')

# %%
# set duration to average of all runs
complex0.iloc[8, 1] = (complex0.iloc[8, 1] + complex1.iloc[8, 1] + complex2.iloc[8, 1] + complex3.iloc[8, 1] + complex4.iloc[8, 1]) / 5
complex0.iloc[8, 2] = (complex0.iloc[8, 2] + complex1.iloc[8, 2] + complex2.iloc[8, 2] + complex3.iloc[8, 2] + complex4.iloc[8, 2]) / 5
complex0.iloc[8, 3] = (complex0.iloc[8, 3] + complex1.iloc[8, 3] + complex2.iloc[8, 3] + complex3.iloc[8, 3] + complex4.iloc[8, 3]) / 5
complex0.iloc[8, 4] = (complex0.iloc[8, 4] + complex1.iloc[8, 4] + complex2.iloc[8, 4] + complex3.iloc[8, 4] + complex4.iloc[8, 4]) / 5
complex0.iloc[8, 5] = (complex0.iloc[8, 5] + complex1.iloc[8, 5] + complex2.iloc[8, 5] + complex3.iloc[8, 5] + complex4.iloc[8, 5]) / 5
complex0.iloc[8, 6] = (complex0.iloc[8, 6] + complex1.iloc[8, 6] + complex2.iloc[8, 6] + complex3.iloc[8, 6] + complex4.iloc[8, 6]) / 5
complex0
# Out:
#      Unnamed: 0  logical_ft_arg  logical_pt  srip_ft_arg   srip_pt  \
# 0   ndcg_burges        0.897490    0.896979     0.894735  0.857758
# 1          ndcg        0.881892    0.883767     0.881443  0.852440
# 2           map        0.727698    0.729574     0.738968  0.708972
# 3            f1        0.660145    0.660145     0.660145  0.660145
# 4        recall        0.976190    0.976190     0.976190  0.976190
# 5     precision        0.521429    0.521429     0.521429  0.521429
# 6   correctness        0.611796    0.666360     0.717469  0.550417
# 7  completeness        0.964286    0.964286     0.964286  0.964286
# 8      duration        0.003790    0.003369     0.004355  0.003802
#
#    treemaps_ft_arg  treemaps_pt
# 0         0.853263     0.784362
# 1         0.854390     0.798175
# 2         0.737267     0.677083
# 3         0.660145     0.660145
# 4         0.976190     0.976190
# 5         0.521429     0.521429
# 6         0.602606     0.533030
# ...
